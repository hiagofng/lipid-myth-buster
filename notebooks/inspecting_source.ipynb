# %%
pip install openpyxl pandas
# Out:
# Requirement already satisfied: openpyxl in C:\Users\hiago.garcia\AppData\Roaming\Python\Python312\site-packages (3.1.5)
# Requirement already satisfied: pandas in C:\Users\hiago.garcia\AppData\Roaming\Python\Python312\site-packages (2.3.3)
# Requirement already satisfied: et-xmlfile in C:\Users\hiago.garcia\AppData\Roaming\Python\Python312\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\hiago.garcia\AppData\Roaming\Python\Python312\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\hiago.garcia\AppData\Roaming\Python\Python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\hiago.garcia\AppData\Roaming\Python\Python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\hiago.garcia\AppData\Roaming\Python\Python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in C:\Users\hiago.garcia\AppData\Roaming\Python\Python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_excel('https://ndownloader.figshare.com/files/14624306')

# %%
print(df.columns.tolist())
# Out:
# ['No_figshare', 'test1_replcation2', 'SBP', 'DBP', 'WEIGHT.', 'BMI', 'GLUCOSE', 'CHOL.', 'CREATININE', 'IDMS.MDRD.GFR', 'TG', 'HDL.CHOL.', 'LDL.CHOL.', 'HS.CRP', 'HB.A1C', 'hypertension', 'diabetes', 'Ex-smoker', 'Current-smoker', 'age_yr', 'Sex', 'CACS']

# %%
print(df.dtypes)
# Out:
# No_figshare            int64
# test1_replcation2      int64
# SBP                  float64
# DBP                  float64
# WEIGHT.              float64
# BMI                  float64
# GLUCOSE              float64
# CHOL.                float64
# CREATININE           float64
# IDMS.MDRD.GFR        float64
# TG                   float64
# HDL.CHOL.            float64
# LDL.CHOL.            float64
# HS.CRP               float64
# HB.A1C               float64
# hypertension           int64
# diabetes               int64
# Ex-smoker              int64
# Current-smoker         int64
# age_yr                 int64
# Sex                   object
# CACS                 float64
# dtype: object

# %%
print(df.head())
# Out:
#    No_figshare  test1_replcation2    SBP   DBP  WEIGHT.   BMI  GLUCOSE  CHOL.  \
# 0            1                  1  116.0  79.0     69.2  22.9    113.0  199.0
# 1            2                  1  124.0  80.0     84.3  28.9     97.0  124.0
# 2            3                  1  115.0  75.0     72.4  24.2    114.0  179.0
# 3            4                  1  128.0  86.0     73.9  26.0    105.0  200.0
# 4            5                  1  120.0  74.0     78.0  23.8     89.0  252.0
#
#    CREATININE  IDMS.MDRD.GFR  ...  LDL.CHOL.  HS.CRP  HB.A1C  hypertension  \
# 0        0.92            NaN  ...      125.0    0.34     5.8             0
# 1        0.90           87.0  ...       53.0    0.38     5.9             1
# 2        0.99           77.1  ...      106.0    0.05     5.9             0
# 3        1.30            NaN  ...        NaN    0.01     6.0             0
# 4        1.20            NaN  ...        NaN    0.13     5.7             0
#
#    diabetes  Ex-smoker  Current-smoker  age_yr  Sex  CACS
# 0         0          1               0      44    M  19.9
# 1         0          1               0      57    M   0.0
# 2         0          0               0      60    M   0.0
# 3         0          1               0      49    M   0.0
# 4         0          1               0      60    M   0.0
#
# [5 rows x 22 columns]

# %%
print(f'Shape: {df.shape}')
# Out:
# Shape: (1688, 22)
